# %% [markdown]
# # FarmTech Solutions — Parte 1: Carregamento e Análise Exploratória
# ## FIAP IA 2026/1 | Fase 3 Cap 10 | Grupo 45
#
# **Responsável:** Vinicius Anjos | **RM:** 572814
# **Branch:** `parte1-vinicius`
#
# ---
# Esta parte cobre o carregamento dos dados, inspeção inicial e os dois primeiros gráficos exploratórios.

# %% [markdown]
# ## 1. Importações e Configuração

# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

sns.set_theme(style='whitegrid', palette='husl')
plt.rcParams['figure.dpi'] = 100

_base = Path(os.getcwd()).resolve()
_csv = None
for candidate in (_base / 'produtos_agricolas.csv', _base.parent / 'produtos_agricolas.csv'):
    if candidate.exists():
        _csv = candidate
        break
if _csv is None:
    raise FileNotFoundError('produtos_agricolas.csv não encontrado na raiz do repositório.')

df = pd.read_csv(_csv)
print(f"Dataset carregado: {df.shape[0]} linhas, {df['label'].nunique()} culturas")
df.head()

# %% [markdown]
# ## 2. Inspeção Inicial dos Dados

# %%
# TODO: Exibir os tipos de cada coluna, quantidade de nulos e estatísticas descritivas
# Dica: use df.info(), df.isnull().sum() e df.describe()

# %% [markdown]
# ## 3. Gráfico 1 — Distribuição das Culturas

# %%
# TODO: Criar um gráfico de barras horizontais mostrando quantas amostras tem por cultura
# Dica: use df['label'].value_counts() e ax.barh()

# %% [markdown]
# ## 4. Gráfico 2 — Distribuição das Variáveis Numéricas

# %%
# TODO: Criar histogramas para N, P, K, temperature, humidity, ph, rainfall
# Dica: subplots 2x4, uma variável por subplot

# %% [markdown]
# ## 5. Suas Conclusões da Parte 1
#
# > Escreva aqui (em markdown) o que você observou nos dados:
# > - O dataset é balanceado?
# > - Alguma variável tem distribuição estranha?
# > - Valores mínimos/máximos que chamaram atenção?
